# %% [markdown]
# # [IAPR 2019:][iapr2019] Lab 1 ‒  Image segmentation
#
# **Author:** Emma Nilsson and Anna Fredriksson Häägg
# **Due date:** 04.04.2019
#
# [iapr2019]: https://github.com/LTS5/iapr-2019

# %% [markdown]
# ## Extract relevant data
# We first need to extract the `lab-01-data.tar.gz` archive.
# To this end, we use the [tarfile] module from the Python standard library.
#
# [tarfile]: https://docs.python.org/3.6/library/tarfile.html

# %%
import tarfile
import os

data_base_path = os.path.join(os.pardir, 'data')
data_folder = 'lab-01-data'
tar_path = os.path.join(data_base_path, data_folder + '.tar.gz')
with tarfile.open(tar_path, mode='r:gz') as tar:
    tar.extractall(path=data_base_path)

# %% [markdown]
# ## Part 1: Brain segmentation
#
# Your goal: compute the size of the brain (in pixels) in a 2D image of a human head taken by Magnetic Resonance Imaging (MRI).
# * Try as many methods as you can, the more the better.
# * At least region growing and contour detection.

# %% [markdown]
# ### 1.1 Brain image visualization

# %%
import skimage.io
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib inline

# Load image
data_path = os.path.join(data_base_path, data_folder)
brain_im = skimage.io.imread(os.path.join(data_path, 'brain-slice40.tiff'))
im_h, im_w = brain_im.shape

fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_im, cmap='gray')
ax.set_title('MRI brain image ({} px, {} px)'.format(im_h, im_w))
ax.axis('off')
plt.show()

# %% [markdown]
# ### Evaluation function
# This function counts the pixels of the brain. All pixels which represent the brain will be set to white, so the function will count the amount of white pixels in the image.

# %%
def compute_brain_size(img):
    white_pixels = np.sum(img == 255) 
    print(white_pixels)

# %% [markdown]
# #### Imports

# %%
import numpy as np
import skimage.exposure as exposure
import skimage.measure as measure
import skimage.morphology as mp
import skimage.filters as filters

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# We start of by doing some preprecessing to see if it can help us later

# %% [markdown]
# First, we make the original image binary by thresholding the image. We tested different values to try to seperate the brain from the rest as mush as possible

# %%
#Thresholding the image between two thresholds
def threshold(image, th1, th2):
    th_img = image.copy()
    th_img[th_img<th1] = 0
    th_img[th_img>th2] = 0
    th_img[(th_img>=th1) & (th_img<=th2)] = 255
    return th_img

# %%
brain_thresh = threshold(brain_im, 60, 100)
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_thresh, cmap='gray')
ax.set_title('Thresholded brain')
# Out:
# Text(0.5,1,'Thresholded brain')

# %% [markdown]
# Now that we have the binary image we want to try some morphilogical functions to remove some of the white areas representing the skull. After some testing we decided on first doing an erosion and then opening

# %%
brain_thresh_mp = mp.opening(mp.erosion(brain_thresh))
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_thresh_mp, cmap='gray')
ax.set_title('Thresholded + erosion and opening')
# Out:
# Text(0.5,1,'Thresholded + erosion and opening')

# %% [markdown]
# Even though this removed some of the scull and such, this didn't really help, since we also removed alot of pixels that actually where part of the brain

# %% [markdown]
# Another preprocessing method would be to perform a Histogram Equalization.

# %%
brain_equalized = skimage.img_as_ubyte(exposure.equalize_adapthist(brain_im, clip_limit=0.01))
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_equalized, cmap='gray')
ax.set_title('Histogram Equalization')
# Out:
# C:\Users\annah\Anaconda3\lib\site-packages\skimage\util\dtype.py:122: UserWarning: Possible precision loss when converting from float64 to uint8
#   .format(dtypeobj_in, dtypeobj_out))
# Text(0.5,1,'Histogram Equalization')

# %% [markdown]
# Finally we will combine the methods by thresholding the equalized image and then opening it.

# %%
brain_eq_thresh_mp = mp.opening(threshold(brain_equalized, 60, 175))
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
ax.imshow(brain_eq_thresh_mp, cmap='gray')
ax.set_title('Histogram Equalization')
# Out:
# Text(0.5,1,'Histogram Equalization')

# %% [markdown]
# ### 1.2 Region growing

# %% [markdown]
# Now we will implement a region growing algorithm besed on thresholds and see how it works for the preprocessed images.

# %%
def region_growing(x, y, img, img_out, processed):
    processed[x, y] = 1
    if (img[x, y] > 0):
        img_out[x, y] = 255
        if(processed[x-1, y] != 1):
            region_growing(x-1, y, img, img_out, processed)
        if(processed[x+1, y] != 1):
            region_growing(x+1, y, img, img_out, processed)
        if(processed[x, y-1] != 1):
            region_growing(x, y-1, img, img_out, processed)
        if(processed[x, y+1] != 1):
            region_growing(x, y+1, img, img_out, processed)

# %%
import sys
sys.setrecursionlimit(10000)

# %% [markdown]
# First we try with the thresholded image. We do a dilation afterwards to fill some of the holes.

# %%
result = brain_im.copy()
region_growing(130, 100, brain_thresh, result, np.zeros(brain_im.shape))
print('Brain size: ' + str(compute_brain_size(result)))
plt.imshow(mp.dilation(result), cmap='gray')

# %% [markdown]
# Now with the image that first was equalized, then thresholded and then processed with morphology operations.

# %%
result = brain_im.copy()
region_growing(130, 100, brain_eq_thresh_mp, result, np.zeros(brain_im.shape))
print('Brain size: ' + str(compute_brain_size(result)))
plt.imshow(mp.dilation(result), cmap='gray')

# %% [markdown]
# As we can see we covered most of the "brain pixels"

# %% [markdown]
# ### 1.3 Contour detection
# Now we will try a few different methods to detect the brains contours

# %% [markdown]
# #### 1.3.1 Using a sobel filer

# %% [markdown]
# First we try by using a sobel filter

# %%
brain_sobel = mp.erosion(filters.sobel(brain_im.copy()))
plt.imshow(brain_sobel, cmap='gray')

# %% [markdown]
# To enhance the contours we use our previosly defined threshold functino as wel as dilation

# %%
plt.imshow(mp.dilation(threshold(skimage.img_as_ubyte(brain_sobel), 20, 35)), cmap='gray')

# %% [markdown]
# The brain is distinguishable but the scull is really more defined than the brain it self

# %% [markdown]
# We will try the same with the equlized image

# %%
brain_eq_sobel = filters.sobel(brain_equalized.copy())
plt.imshow(brain_eq_sobel, cmap='gray')

# %% [markdown]
# It is better but still hard the brain itself is still har to extract

# %% [markdown]
# #### 1.3.2 The "find_contours" function

# %%
r = brain_im.copy()

# Find contours
contours = measure.find_contours(r, 41)

# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(r, interpolation='nearest', cmap=plt.cm.gray)

for n, contour in enumerate(contours):
    if (len(contour) >500):
        print(n)
        ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
# Out:
# 0
# 64

# %% [markdown]
# As we can see this function provides us with alot of functinos, however they doesn't really work as espected. The orange contour almost covers the brain, but really it surrounds the black area outside the brain.

# %% [markdown]
# #### 1.3.3 Active contours

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
from skimage import data
from skimage.filters import gaussian
from skimage.segmentation import active_contour


img = data.astronaut()
img = rgb2gray(img)

s = np.linspace(0, 2*np.pi, 400)
x = 128 + 80*np.cos(s)
y = 150 + 80*np.sin(s)
init = np.array([x, y]).T
img = brain_im.copy()
snake = active_contour(gaussian(img, 3),
                       init, alpha=0.015, beta=0.0001, gamma=0.1, w_line=-1)

fig, ax = plt.subplots(figsize=(7, 7))
ax.imshow(img, cmap=plt.cm.gray)
ax.plot(init[:, 0], init[:, 1], '--r', lw=3)
ax.plot(snake[:, 0], snake[:, 1], '-b', lw=3)
ax.set_xticks([]), ax.set_yticks([])
ax.axis([0, img.shape[1], img.shape[0], 0])
# Out:
# [0, 256, 256, 0]

# %% [markdown]
# This is definately the best method yet. Unfourtunately it demands som finetuneing when selecting the initial area but the result is good. We will use this contour to compute the area

# %%
from numpy import trapz

x = snake[:, 0]
y = snake[:, 1]

# Compute the area using the composite trapezoidal rule.
area = trapz(x,y)
print("area =", int(area))
# Out:
# area = 19705

# %% [markdown]
# ## Part 2: Save the bees !
#
# Varroa mites are recognized as the biggest pest to honey bees worldwide, and are believed to be the single largest contributing factor in the modern-day decline of honey bees due to their ability to transmit diseases, resulting in death or severe deformity of the pupae.
#
# Detecting and quantifying the presence of Verroa in a beehive is therefore crucial to treat the infection appropriately and as early as possible, and image analysis appears very useful in this problem.
#
# ![Varroa Mite](https://lts5www.epfl.ch/wp-content/uploads/2018/07/varroa-2.jpg)
#
#
#
# ### 2.1 Introduction to Project
#
# You will find hereafter a set of 4 images taken under real conditions. In this task you will be ask to:
# 1. Count the number of Varroa on each picture
# 2. Determine the Intersection over Union of the detected patterns w.r.t. the ground truth
# 3. Estimate the Precision, Recall and F1-score at two different IoU thresholds $T = {0.5 \text{, and } 0.9}$
#
#
# **Note**
#
# Try to have the same routine(s) running on the four images, and giving (approximatively) the same results. The routine(s) that you will write for this part will be useful for the final project as well, so pay special attention to it.
#
# #### Vocabulary
#
#
# * **IoU**: Let $A$ be the ground truth area and $B$ the predicted one. the intersection over union (IoU) is given as:
# $$IoU(A,B) = \frac{A \cap B}{A \cup B} = \frac{\text{Area of Overlap}}{\text{Area of Union}}$$
# Let $T$ be a scalar in the interval $[0, 1]$, then $B$ will be considered as a true positive (TP) if and only if $IoU(A,B) \ge T$. As a results, we can evaluate the performance of our detection with different values of $T$. The larger $T$ is, the more constraining is our condition.
#
#
# * **Precision**: The precision is given as:
# $$precision = \frac{tp}{tp + fp}$$
# where $tp$ is the number of true positives and $fp$ the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
#
# * **Recall**: The recall is given as:
# $$precision = \frac{tp}{tp + fn}$$
# where $tp$ is the number of true positives and $fn$ the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
#
# * **F1-score**: The F1 score can be interpreted as a weighted average of the precision and recall, where an F1 score reaches its best value at 1 and worst score at 0. The relative contribution of precision and recall to the F1 score are equal. The formula for the F1 score is:
# $$F1 = \frac{2 \cdot precision \cdot recall}{precision + recall}$$
#
#
# **FAQ**
#
# Q: What to do if I have multiple ground truth $A_i$ and candidates $B_j$ and want to find the best set $(i,j)$ such that $(i, j) = \arg\max_{i,j} IoU(A_i, B_j)$ ?
#
# A: Here, we recommend to use a brute force approach. It corresponds to compute $IoU(A, B)$ for every possible pairs (i,j) and keep the pair with the highest $IoU$. Note that a candidate $B_j$ can **only** be matched to **one** ground truth area $A_i$.

# %% [markdown]
# Here, we visualize the 4 images for our patern detection

# %%
# Load images
im_names = ['varroa-01', 'varroa-02', 'varroa-03', 'varroa-04']
filenames = [os.path.join(data_path, name) + '.jpg' for name in im_names]
ic = skimage.io.imread_collection(filenames)
print('Number of images: ', len(ic))
# Out:
# Number of images:  4

# %%
# Plot images
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
for ax, im, nm in zip(axes.ravel(), ic, im_names):
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %% [markdown]
# We can as well add the groud truth label that are stored in the corresponding XML files. Each xml file stores the position of the varroa on the image as :
#
# ```xml
# <annotation>
# 	<object>
# 		<name>Varroa</name>
# 		<difficult>0</difficult>
# 		<bndbox>
# 			<xmin>14</xmin>
# 			<ymin>117</ymin>
# 			<xmax>33</xmax>
# 			<ymax>137</ymax>
# 		</bndbox>
# 	</object>
# 	<object>
# 		...
# 	</object>
# 	...
# </annotation>
# ```
# The block `object` defines the attributes of the varroa. `name` is the definition of the object class (always varroa). `bndbox` is the definition of the bounding box. To simplify your task, we implemented a function named `parse_file` that returns an array with the bounding box of the varroa expressed as `(x, y, width, heigth)` which corresponds to `(xmin, ymin, xmax-xmin, ymax-ymin)`

# %%
import xml.etree.ElementTree as ET

def parse_file(filename):
    """ Parse a PASCAL VOC xml file """
    tree = ET.parse(filename)
    objects = []
    for obj in tree.findall('object'):
        obj_struct = {}
        obj_struct['name'] = obj.find('name').text
        bbox = obj.find('bndbox')
        obj_struct['bbox'] = [int(float(bbox.find('xmin').text)),
                              int(float(bbox.find('ymin').text)),
                              int(float(bbox.find('xmax').text))-int(float(bbox.find('xmin').text)),
                              int(float(bbox.find('ymax').text))-int(float(bbox.find('ymin').text))]
        objects.append(obj_struct)

    return objects

# %%
annotations_xmls = [parse_file(os.path.join(data_path, name) + '.xml') for name in im_names]

# %%
# Plot images
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
for ax, im, nm, annotations in zip(axes.ravel(), ic, im_names, annotations_xmls):
    # Iterate over annotations
    for anno in annotations:
        rect = patches.Rectangle((anno['bbox'][0], anno['bbox'][1]), anno['bbox'][2], anno['bbox'][3],
                linewidth=1,edgecolor='r',facecolor='none')
        ax.add_patch(rect)
    
    ax.imshow(im)
    ax.axis('off')
    ax.set_title(nm)
plt.show()

# %% [markdown]
# ### 2.2 Count the number of Varroa on each picture
#
# Add your implementation and discussion
#
# Hint: `skimage.measure.label` might be useful to label the thresholded image

# %%
def remove_yellow(img):
    out = img.copy()
    
    red = out[:,:,0]
    green = out[:,:,1]
    blue = out[:,:,2]
    
    is_yellow =  (red > 100) & (red < 250) & (green > 100) & (green < 250) & (blue > 0) & (blue < 200)
    
    red[is_yellow] = 255
    green[is_yellow] = 255
    blue[is_yellow] = 255
    
    out[:,:,0] = red
    out[:,:,1] = green
    out[:,:,2] = blue
    
    return out

# %%
img = remove_yellow(ic[3])
print(img.shape)
# Out:
# (622, 763, 3)

# %%
img_g = rgb2gray(img)
plt.imshow(img_g, cmap='gray')

# %%
img_th = mp.erosion(threshold(skimage.img_as_ubyte(img_g), 1, 100))
plt.imshow(img_th, cmap='gray')

# %%
labels, num_labels = measure.label(img_th, connectivity=2, return_num=True)
properties = measure.regionprops(labels)
bugs = []
for prop in properties:
    if (prop.area > 200):
        bugs.append(prop)
len(bugs)
# Out:
# 16

# %% [markdown]
# ### 2.3 IoU of the detected pattern w.r.t. the ground truth
#
# Add your implementation and discussion
#
# Hint: `skimage.measure.regionprops` implements a large variety of descriptors

# %% [markdown]
# ### 2.4 Precision, Recall and F1-score at two different IoU thresholds
#
# Add your implementation and discussion
